# %% [markdown]
# # HERE WE WILL IMPORT THE REQUIRED LIBRARIES

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
ipl = pd.read_csv("Match.csv")

# %%
ipl
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# ..        ...       ...                          ...
# 632       632   1082646             Delhi Daredevils
# 633       633   1082647               Mumbai Indians
# 634       634   1082648          Sunrisers Hyderabad
# 635       635   1082649               Mumbai Indians
# 636       636   1082650               Mumbai Indians
#
#                            Team2 match_date  Season_Year  \
# 0          Kolkata Knight Riders  4/18/2008         2008
# 1            Chennai Super Kings  4/19/2008         2008
# 2               Rajasthan Royals  4/19/2008         2008
# 3    Royal Challengers Bangalore  4/20/2008         2008
# ...

# %%
ipl.shape
# Out:
# (637, 17)

# %%
matches= ipl[["Team1","Team2"]]

# %%
matches
# Out:
#                            Team1                        Team2
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 632             Delhi Daredevils  Royal Challengers Bangalore
# 633               Mumbai Indians      Rising Pune Supergiants
# 634          Sunrisers Hyderabad        Kolkata Knight Riders
# 635               Mumbai Indians        Kolkata Knight Riders
# 636               Mumbai Indians      Rising Pune Supergiants
#
# [637 rows x 2 columns]

# %%
matches.head()
# Out:
#                          Team1                        Team2
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# 3               Mumbai Indians  Royal Challengers Bangalore
# 4        Kolkata Knight Riders              Deccan Chargers

# %% [markdown]
# # NOW WE WILL START OUR ANALYSIS ON THE LOADED DATA SET

# %%
ipl
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# ..        ...       ...                          ...
# 632       632   1082646             Delhi Daredevils
# 633       633   1082647               Mumbai Indians
# 634       634   1082648          Sunrisers Hyderabad
# 635       635   1082649               Mumbai Indians
# 636       636   1082650               Mumbai Indians
#
#                            Team2 match_date  Season_Year  \
# 0          Kolkata Knight Riders  4/18/2008         2008
# 1            Chennai Super Kings  4/19/2008         2008
# 2               Rajasthan Royals  4/19/2008         2008
# 3    Royal Challengers Bangalore  4/20/2008         2008
# ...

# %%
highest_toss_winner = ipl["Toss_Winner"].value_counts()

# %%
highest_toss_winner
# Out:
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Rising Pune Supergiants        12
# Kochi Tuskers Kerala            8
# Rising Pune Supergiant          1
# Name: Toss_Winner, dtype: int64

# %%
plt.figure(figsize=(22,5))
plt.title("HIGHEST TOSS WINNERS GRAPH")
plt.xlabel("TEAM NAME")
plt.ylabel("No. Of Wins")
plt.plot(highest_toss_winner)
plt.show()

# %%
plt.figure(figsize=(22,5))
plt.title("HIGHEST TOSS WINNERS GRAPH")
plt.xlabel("TEAM NAME")
plt.ylabel("No. Of Wins")
plt.bar(list(ipl["Toss_Winner"].value_counts()[0:10].keys()), ipl["Toss_Winner"].value_counts()[0:10])
plt.show()

# %%
ipl
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# ..        ...       ...                          ...
# 632       632   1082646             Delhi Daredevils
# 633       633   1082647               Mumbai Indians
# 634       634   1082648          Sunrisers Hyderabad
# 635       635   1082649               Mumbai Indians
# 636       636   1082650               Mumbai Indians
#
#                            Team2 match_date  Season_Year  \
# 0          Kolkata Knight Riders  4/18/2008         2008
# 1            Chennai Super Kings  4/19/2008         2008
# 2               Rajasthan Royals  4/19/2008         2008
# 3    Royal Challengers Bangalore  4/20/2008         2008
# ...

# %%
win_batting_first = ipl[ipl["Win_Type"]!= "wickets"]

# %%
win_batting_first.head()
# Out:
#     Match_SK  match_id                        Team1                  Team2  \
# 0          0    335987  Royal Challengers Bangalore  Kolkata Knight Riders
# 1          1    335988              Kings XI Punjab    Chennai Super Kings
# 7          7    335994          Chennai Super Kings         Mumbai Indians
# 9          9    335996              Kings XI Punjab         Mumbai Indians
# 14        14    336001  Royal Challengers Bangalore    Chennai Super Kings
#
#    match_date  Season_Year                                  Venue_Name  \
# 0   4/18/2008         2008                       M Chinnaswamy Stadium
# 1   4/19/2008         2008  Punjab Cricket Association Stadium, Mohali
# 7   4/23/2008         2008             MA Chidambaram Stadium, Chepauk
# 9   4/25/2008         2008  Punjab Cricket Association Stadium, Mohali
# 14  4/28/2008         2008                       M Chinnaswamy Stadium
#
#      City_Name Country_Name                  Toss_Winner  \
# ...

# %%
win_batting_first.value_counts()
# Out:
# Match_SK  match_id  Team1                        Team2                    match_date  Season_Year  Venue_Name                                City_Name           Country_Name  Toss_Winner                  match_winner                 Toss_Name  Win_Type  Outcome_Type  ManOfMach    Win_Margin  Country_id
# 0         335987    Royal Challengers Bangalore  Kolkata Knight Riders    4/18/2008   2008         M Chinnaswamy Stadium                     Bangalore           India         Royal Challengers Bangalore  Kolkata Knight Riders        field      runs      Result        BB McCullum  140.0       1             1
# 407       729302    Rajasthan Royals             Chennai Super Kings      4/23/2014   2014         Dubai International Cricket Stadium       Abu Dhabi           U.A.E         Rajasthan Royals             Chennai Super Kings          field      runs      Result        RA Jadeja    7.0         3             1
# ...

# %%
plt.figure(figsize=(15,4))
plt.title("GRAPH OF HIGHEST TOSS WINNERS")
plt.xlabel("Team name")
plt.ylabel("no. of wins")

p
plt.show()
# Out:
#   Cell In[35], line 6
#     plt.plot( ipl[ipl["Win_Type"]!= "wickets")
#                                              ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['
